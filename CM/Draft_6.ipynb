# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import random

# %%
def dist(a, b):
    return np.linalg.norm(np.array(a) - np.array(b))

# %%
a = 0.4
h = 0.01

# %%
def f(dot):
    global a
    x, y = dot
    return x + y + a * x * (1 - x ** 2), y + a * x * (1 - x ** 2)

# %%
def f1(dot):
    global a
    x, y = dot
    return x + y + a * x * (1 - x ** 2), y + a * x * (1 - x ** 2)

# %%
def c_func(a, b):
    return (a[0] + b[0]) / 2, (a[1] + b[1]) / 2

# %%
def main_func(a, b):
    if dist(f(a), f(b)) > h:
        c = c_func(f(a), f(b))
        main_func(f(a), c)
        main_func(c, f(b))
    else:
        glist.append(f(b))

# %%
# %%time
A = 1, 0
B = -1, 0
glist = [f(A)]
main_func(A, B)
# Out:
# Wall time: 694 ms

# %%
plt.plot(*list(zip(*glist)))

# %%
len(glist)
# Out:
# 347
