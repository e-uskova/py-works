# %% [markdown]
# # Обработка изображений и системы компьютерного зрения
#
# ## "Обработка изображений в библиотеках SciPy и Matplotlib"

# %% [markdown]
# Выполнила **Ускова Екатерина**, группа **ИС/м-21-1-з**.
#
# 2023 год

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# Matplotlib - это графическая библиотека. В этом разделе дается краткое введение в модуль matplotlib.pyplot, который предоставляет систему построения графиков, аналогичную системе MATLAB.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# Запустив эту специальную команду iPython,графики будут встроены в документ:

# %%
# %matplotlib inline

# %% [markdown]
# #### Графики

# %% [markdown]
# Самая важная функция в `matplotlib` - это `plot`, которая позволяет вам строить графики для двумерных данные. Вот простой пример:

# %%
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)

# %% [markdown]
# Немного усложнив пример мы можем легко построить несколько строк одновременно и добавить метки заголовка, легенды и оси:

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

# %% [markdown]
# #### <font color=red>Задание</font>
# Построить графики функций: $y=\sin(x)$,$y=\cos(x)$, $y=tg(x)$, $y=ctg(x)$.
# Требования к графикам:
# - все графики в одной системе координат
# - значения по оси x должны меняться от $-\pi$ до $\pi$.
# - подписи по осям координат
# - название графика
# - координатная сетка
# - легенда.

# %%
# Выполнение задания.
x = np.linspace(-np.pi, np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)
y_ctg = 1 / y_tan

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.plot(x, y_tan)
plt.plot(x, y_ctg)
plt.grid()
plt.ylim(-10, 10)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Trigonometric functions')
plt.legend(['Sin', 'Cos', 'Tan', 'Ctg'])

# %% [markdown]
# #### Подграфики

# %% [markdown]
# Вы можете изображать разные графики на том же рисунке, используя функцию `subplot`. /пример:

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %% [markdown]
# Вы можете больше узнать о функции `subplot` в [документации](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot).

# %% [markdown]
# #### <font color=red>Задание</font>
# Построить графики функций: $y=2\cdot x^2$, $y=-2\cdot x^2$, $x=2\cdot y^2$, $x=-2\cdot y^2$
# Требования к графикам:
# - каждый график построить в своей системе координат, разделив лист на 4 равные части 2х2.
# - значения по осям x и y должны меняться от 5 до 5.
# - подписи по осям координат
# - названия графиков
# - координатная сетка.

# %%
# Выполнение задания.
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

y1 = 2 * x ** 2
y2 = -2 * x ** 2
x1 = 2 * y ** 2
x2 = -2 * y ** 2

plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.grid()
plt.ylim(-5, 5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('y = 2 * x ^ 2')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.grid()
plt.ylim(-5, 5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('y = -2 * x ^ 2')

plt.subplot(2, 2, 3)
plt.plot(x1, y)
plt.grid()
plt.xlim(-5, 5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('x = 2 * y ^ 2')

plt.subplot(2, 2, 4)
plt.plot(x2, y)
plt.grid()
plt.xlim(-5, 5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('x = -2 * y ^ 2')

plt.subplots_adjust(wspace=0.5, hspace=1)

# %% [markdown]
# #### Гистограммы
# Для построения гистограмм в IPython можно использовать разные способы. Расчет гистограммы оптимизированный для массивов с большим количеством элементов выполняется при помощи функции `np.histogram` из библиотеки NumPy. Например:

# %%
np.histogram([1, 2, 1, 1, 2, 0], bins=[0, 1, 2, 3])
# Out:
# (array([1, 3, 2], dtype=int64), array([0, 1, 2, 3]))

# %% [markdown]
# Для вычисления относительных значений в гистограмме можно использовать параметр `density=True`

# %%
np.histogram([1, 2, 1, 1, 2, 0], bins=[0, 1, 2, 3],density=True)
# Out:
# (array([0.16666667, 0.5       , 0.33333333]), array([0, 1, 2, 3]))

# %% [markdown]
# Для построения графика гистограммы в Matplotlib есть соответствующая, функция, которая основана на функции библиотеки NumPy:

# %%
plt.hist([1, 2, 1, 1, 2, 0], bins=[0, 1, 2, 3])
# Out:
# (array([1., 3., 2.]), array([0, 1, 2, 3]), <BarContainer object of 3 artists>)

# %%
plt.hist([1, 2, 1, 1, 2, 0], bins=[0, 1, 2, 3],density=True)
# Out:
# (array([0.16666667, 0.5       , 0.33333333]),
#  array([0, 1, 2, 3]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# #### <font color=red>Задание</font>
# Сгенерировать 1000 случайных значений выбранного распределения (вид уточнить у преподавателя) и построить гистограмму частот и гистограмму относительных частот.
# Требования к графикам:
# - графики расположить горизонтально
# - подписи по осям координат
# - названия графиков.

# %%
# Выполнение задания.
x = np.random.normal(0, 1, 1000)

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.hist(x)
plt.xlabel('x')
plt.ylabel('Частота')
plt.title('Гистограмма частот')

plt.subplot(1, 2, 2)
plt.hist(x, density=True)
plt.xlabel('x')
plt.ylabel('Относительная частота')
plt.title('Гистограмма относительных частот')
# Out:
# Text(0.5, 1.0, 'Гистограмма относительных частот')

# %% [markdown]
# #### Диаграммы рассеивания (Scatter plot)
# Диаграмма рассеивания представляет собой график, в котором точки не соединяются отрезками линий, а представлены по отдельности точками, кругами или другими фигурами на графике.
#
# Пример построения диаграммы рассеивания с использованием функции `plot` библиотеки `matplotlib`:

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, 'o', color='black');

# %% [markdown]
# Используя функцию `plot` можно совместить диаграмму рассеивания и линейный график:

# %%
 plt.plot(x, y, '-ok');  # линия (-), маркер круга (o), черный цвет (k)

# %% [markdown]
# Также диаграммы рассеивания могут быть построены с использованием функции `scatter` библиотеки `matplotlib`:

# %%
 plt.scatter(x, y, marker='o');

# %% [markdown]
# Основное различие между функциями `plt.scatter` и `plt.plot` состоит в том, что с помощью первой можно создавать диаграммы рассеяния с индивидуально задаваемыми (или выбираемыми в соответствии с данными) свойствами каждой точки (размер, цвет заливки, цвет рамки и т. д.).
#
# Продемонстрируем это, создав случайную диаграмму рассеяния с точками различных цветов и размеров. Чтобы лучше видеть перекрывающиеся результаты, воспользуемся ключевым словом `alpha` для настройки уровня прозрачности:

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3)
plt.colorbar();  # Отображаем цветовую шкалу

# %% [markdown]
# #### <font color=red>Задание</font>
# Повторить крайний пример, изменив вид распределений, используемый для генерации массивов x и y (вид распределений уточнить у преподавателя).

# %%
rng = np.random.RandomState(3)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3)
plt.colorbar();  # Отображаем цветовую шкалу

# %% [markdown]
# ### SciPy

# %% [markdown]
# SciPy основывается на массивах и операциях над массивами библиотеки NumPy и предоставляет большое количество функций, которые работают с массивами Numpy и полезны для различных научных и инженерных приложений.
#
# Лучший способ познакомиться с SciPy - изучить [документацию](http://docs.scipy.org/doc/scipy/reference/index.html). Мы выделим некоторые части SciPy, которые могут оказаться полезными для изучения материалов курса.

# %% [markdown]
# #### Работа с изображениями

# %% [markdown]
# SciPy предоставляет некоторые базовые функции для работы с изображениями. Например, функции для чтения изображений с диска в массивы numpy, для сохранения массивов numpy на диск как изображений и для изменения изображений. Вот простой пример, демонстрирующий эти функции:

# %%
# from scipy.misc import imread, imsave, imresize
from imageio import imread, imsave
from skimage.transform import resize as imresize

# Читаем изображение из файла JPEG в массив numpy.
img = imread('files/cat.jpg')
print(img.dtype, img.shape)  # "uint8 (400, 248, 3)"

# Мы можем изменить оттенок изображения, масштабируя каждый из цветовых каналов
# с помощью константы. Изображение имеет форму (400, 248, 3);
# мы умножаем его на массив [1, 0.95, 0.9] формы (3);
# Трансляция массивов numpy привеодит к тому, что красный канал не изменит значение,
# а зеленый и синий каналы будут умножены на 0,95 и 0,9 соответственно.
img_tinted = img * [1, 0.95, 0.9]

# Изменим размер изображения на 300x300.
img_tinted = imresize(img_tinted, (300, 300))

# Сохраним на диск обработанное изображение.
imsave('files/cat_tinted.jpg', img_tinted.astype(np.uint8))
# Out:
# uint8 (400, 248, 3)

# %% [markdown]
# Вы можете использовать функцию `imshow` из `matplotlib` для отображения изображений. Вот пример:

# %%
img = imread('files/cat.jpg')
img_tinted = img * [1, 0, 0.9]

fig=plt.figure(figsize=(16, 8)) # Установим размер фигуры для отрисовки графиков.

# Отобразим исходное изображение
plt.subplot(1, 2, 1)
plt.imshow(img)

# Отобразим измененное изображение
plt.subplot(1, 2, 2)

# Небольшая проблема с imshow заключается в том, что функция может дать странные результаты
# если данные не являются uint8. Чтобы избежать этого, нужно привести изображение к типу 
# uint8 перед его отображением.
plt.imshow(np.uint8(img_tinted))
plt.show()

# %% [markdown]
# ### Работа с датасетом CIFAR-10

# %% [markdown]
# Датасет [CIFAR-10](http://www.cs.toronto.edu/~kriz/cifar.html) создан в Канадском институте перспективных исследований и представляет собой набор изображений, которые обычно используются для машинного обучения и алгоритмов компьютерного зрения. Это один из наиболее широко используемых датасетов для исследования машинного обучения.
#
# Датасет CIFAR-10 содержит 60 000 цветных изображений 32x32 принадлежащих 10 различным классам: самолеты, автомобили, птицы, кошки, олени, собаки, лягушки, лошади, корабли и грузовики. 50000 изображений используются для обучения и 10000 тестовых изображений. Всего в датасете содержится 6000 изображений для каждого класса.
# На [странице датасета CIFAR-10](http://www.cs.toronto.edu/~kriz/cifar.html) можно загрузить архив c датасетом для Python по [ссылке](http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).
# После распаковки архива будут доступны 6 пакетов (файлов), каждый из которых представляет набор изображений (пять для обучения и один для проверки).

# %%
# !dir /b files\cifar-10-batches-py
# Out:
# batches.meta
# data_batch_1
# data_batch_2
# data_batch_3
# data_batch_4
# data_batch_5
# readme.html
# test_batch

# %% [markdown]
# Каждый файл можно загрузить в среду IPython используя функцию `unpickle`:

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %% [markdown]
# Загруженные таким образом, каждый из пакетных файлов содержит словарь со следующими объектами:
# - **batch_label** - название пакета
# - **labels** - список из 10000 номеров в диапазоне 0-9. i-е число указывает метку i-го изображения массиве изображений.
# - **data** - массив numpy 10000x3072 типа `uint8`. Каждая строка массива хранит цветное изображение размером 32x32. Первые 1024 записи содержат значения яркости красного канала, последующих 1024 записи - зеленого, и последние 1024 - синего. Изображение хранится в строчном порядке, так что первые 32 элемента массива являются значениями красного канала для первой строки изображения.
# - **filenames** - список названий файлов соответствующих каждому из 1000 изображений.
#
# В наборе данных содержится еще один файл, называемый `batches.meta`. Он также хранит словарь Python, который содержит следующие записи:
# -  **label_names** - список из 10 элементов, который дает значащие имена для числовых меток в массиве меток, описанных выше. `label_names[0] == "airplane"`, `label_names[1] == "automobile"` и т.д.

# %%
cifar_test=unpickle("files/cifar-10-batches-py/test_batch")
print(type(cifar_test)) # Тип данных объекта, полученного их пакетного файла.
# Out:
# <class 'dict'>

# %%
print(type(cifar_test[b'data'])) # Тип данных объекта data.
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# #### <font color=red>Задание</font>
# 1. Загрузить один из шести пакетов (согласно указания преподавателя) и напечатать информацию о типах всех, хранящихся в нем объектов.
# 2. Загрузить файл с метаданными `batches.meta` и напечатать все метки классов и соответствующие им индексы.
# 3. Напечатать индексы и метки классов первых 10 изображений из пакетного файла.

# %%
# Выполнение задания
batch_1=unpickle("files/cifar-10-batches-py/data_batch_1")
print(type(batch_1))
# Out:
# <class 'dict'>

# %%
batches_meta = unpickle("files/cifar-10-batches-py/batches.meta")
label_names = batches_meta[b'label_names']
for i, name in enumerate(label_names):
    print(i, name.decode('UTF-8'))
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %%
for i in range(10):
    label = batch_1[b'labels'][i]
    print(label, label_names[label].decode('UTF-8'))
# Out:
# 6 frog
# 9 truck
# 9 truck
# 4 deer
# 1 automobile
# 1 automobile
# 2 bird
# 7 horse
# 8 ship
# 3 cat

# %% [markdown]
# Каждая строка массива **data** может быть представлена в виде numpy массива формы (colors=3,witdth=32,heigth=32), однако для отображения цветных изображений в библиотеке matplotlib используется представление в виде массива с формой (width=32,heigth=32,colors=3), поэтому для отображения нужно выполнить следующие преобразования:
# - исходный массив строку преобразовать в трехмерный массив размерности (3,32,32), используя `np.reshape`
# - изменить порядок размерностей в трехмерном массиве, используя `np.transpose`
#
# После этого можно отобразить картинку используя `plt.imshow`

# %% [markdown]
# #### <font color=red>Задание</font>
# 1. Отобразить первое изображение из пакетного файла
# 2. Сформировать групповое изображение из первых 9 изображений путем объединения (используя `np.hstack` и `np.vstack`) по 3 исходных изображения в строке и 3 исходных изображения в столбце. Отобразить групповое изображение.
# 3. Создать и напечатать матрицу строк 3x3, с названиями классов этих изображений соответственно их расположению в групповом изображении.

# %%
# Выполнение задания
def transform_image(image):
    image = np.reshape(image, (3, 32, 32))
    image = np.transpose(image, (1, 2, 0))
    return image

img = transform_image(batch_1[b'data'][0])
plt.imshow(img)

# %%
imgs = np.array([transform_image(batch_1[b'data'][i]) for i in range(9)])
imgs_grouped = np.hstack([imgs[i:i+3] for i in [0, 3, 6]])
imgs_grouped = np.hstack(imgs_grouped)
plt.imshow(imgs_grouped)

# %%
imgs_labels = np.array([label_names[batch_1[b'labels'][i]].decode('UTF-8') for i in range(9)])
imgs_labels = imgs_labels.reshape((3, 3))
print(imgs_labels)
# Out:
# [['frog' 'truck' 'truck']
#  ['deer' 'automobile' 'automobile']
#  ['bird' 'horse' 'ship']]

# %% [markdown]
# #### <font color=red>Задание</font>
# 1. Для каждого из 9 изображений отобразить гистограмму яркости красного канала. Гистограммы расположить в области 3x3 соответственно.
# 2. Для каждого из 9 изображений отобразить гистограмму яркости зеленого канала. Гистограммы расположить в области 3x3 соответственно.
# 3. Для каждого из 9 изображений отобразить гистограмму яркости синего канала. Гистограммы расположить в области 3x3 соответственно.
# 4. Обнулить яркости синего и зеленого каналов в групповом изображении (используя матричные операции) и отобразить его.
# 5. Обнулить яркости красного канала в групповом изображении (используя матричные операции) и отобразить его.

# %%
# Выполнение задания
red_ch = imgs[:,:,:,0]
plt.figure(figsize=(12, 6))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.hist(red_ch[i].ravel(), color='red')

# %%
# Выполнение задания
red_ch = imgs[:,:,:,1]
plt.figure(figsize=(12, 6))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.hist(red_ch[i].ravel(), color='green')

# %%
# Выполнение задания
red_ch = imgs[:,:,:,2]
plt.figure(figsize=(12, 6))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.hist(red_ch[i].ravel(), color='blue')

# %%
plt.imshow(imgs_grouped * [1, 0, 0])

# %%
plt.imshow(imgs_grouped * [0, 1, 1])

# %%
plt.imshow(imgs_grouped * [1, 0, 0] + imgs_grouped * [0, 1, 1])
